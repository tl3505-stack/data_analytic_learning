# %%
# Instructions
# This assignment is related to the module, Ensemble Models. The questions that follow are based on dataset of popular songs.

# Spotify Data
# This dataset describes popular songs based on genre and auditory features such as loudness and tempo.

# Variable Description
# Here is a description of Variables included in the dataset. Your goal is to predict the last variable, rating.  

# Here is a description of Variables included in the dataset. The outcome variable is 'rating'.  

# 0. id: Song id
# 1. performer: Performer name
# 2. song: Song name
# 3. genre: Genre
# 4. track_duration: Duration in milliseconds
# 5. track_explicit: Is explicit
# 6. danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# 7. energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# 8. key: The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# 9. loudness: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
# 10. mode: Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
# 11. speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# 12. acousticness: A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# 13. instrumentalness: Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# 14. liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# 15. valence: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# 16. tempo: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# 17. time_signature: Time signature
# 18. rating: Rating derived from Billboard Top 100 and popularity on Spotify. The values of rating were constructed by the authors of the dataset and are not to be used outside the context of this assignment.  
# 19. to 29. genre_country, genre_blues, genre_jazz, genre_rap, genre_space, genre_dance, genre_pop, genre_rock, genre_hip_hop, genre_rnb: Ten genre_ dummy variables derived from genre.

# %%
# Read the data into an object called data. Drop the following variables: id, performer, song, genre, key. 
# Separate the outcome variable from the features, assigning rating to a Series, y, and assigning the remaining features to a DataFrame, X.  
# Next, create a binned outcome variable as follows to divide the outcome variable into 20 equally sized bins: 

# import pandas as pd   
# y_binned = pd.qcut(data.rating, q = 20)  
# Finally, use y_binned to do stratified random sampling keeping 70% of the data in the train sample and the remaining 30% in the test sample. Set random_state to 1031 for reproducibility.

# What is the median value of liveness in the train sample?

# %%
# Construct a linear regression model to predict rating using all ten genre_ dummy variables. What is the RMSE in the train sample?

# %%
# Construct a tree model to predict rating using all ten genre_ dummy variables. Use max_depth = 4. What is the RMSE in the train sample?

# %%
# Combine the two models constructed above using a Voting model. What is the train sample RMSE?

# %%
# Construct a Bagging model with 100 bootstrapped samples. Fit regression tree models using all predictors. 
# Set max_depth to 10. What is the RMSE in the train sample?

# %%
# Next, construct another bagging model with 100 bootstrapped samples, but this time fit a linear regression with all predictors.
# What is the RMSE in the train sample?

# %%
# Now, fit a Random Forest model with 100 bootstrapped samples. Use all predictors. What is the RMSE in the train sample?

# %%
# Based on the Random Forest model constructed above, which of the following is the most important feature?

# %%
# Which of the following models has the lowest Out of Bag (OOB) score?

# %%
# Construct a Boosting model using Adaboost with a tree estimator. Use 100 estimators. Use all predictors. What is the RMSE in the train sample?

# %%
# Now, construct a Boosting model using Gradient Boosting with 100 trees. Use all predictors. What is the RMSE in the train sample?

# %%
# Now, construct a Boosting model using Stochastic Gradient Boosting with 100 trees. Set max_features to 0.4 and subsample to 0.6. Use all predictors. 
# What is the RMSE in the train sample?

# %%
# Based on the Stochastic Gradient Boosting model constructed in the previous question, which of the following is the most important feature?
